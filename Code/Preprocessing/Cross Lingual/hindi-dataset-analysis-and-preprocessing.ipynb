# %%
import numpy as np # linear algebra
import pandas as pd

# %%
sarcastic_df = pd.read_csv('/kaggle/input/hindi-tweets-dataset-for-sarcasm-detection/Sarcasm_Hindi_Tweets-SARCASTIC.csv')

# %%
non_sarcastic_df = pd.read_csv('/kaggle/input/hindi-tweets-dataset-for-sarcasm-detection/Sarcasm_Hindi_Tweets-NON-SARCASTIC.csv')

# %%
sarcastic_df['label'] = 1  # Add a label column with value 1 for sarcastic
non_sarcastic_df['label'] = 0  # Add a label column with value 0 for non-sarcastic

# %%
sarcastic_df
# Out:
#              username                                           acctdesc  \
# 0     Lokeshk67004736                                                NaN
# 1        prayagraj_AU  सत्यमेव जयते\n\nभगवा ध्वज भारत का ऐतिहासिक एवं...
# 2          brand_dbm1  संस्थापक #भगवारक्षकटीम         राम राम दोस्तो🙏...
# 3         Singh8Ankan  हिन्दू हूँ तो हिंदुत्व की बात ही करूँगा।जय श्र...
# 4     PfCEAtft7vvZQRA  हम जिहादियों वामपंथियों कांग्रेसियों सपाइयों क...
# ...               ...                                                ...
# 6046        _Harsh_Jr  Nikal Pehli Fursaat Mein 😎 ||\nHarHarMahadev 🙏...
# 6047        BUDHLADA_  NATION BUILDER AND CHANGE MAKER THROUGH TECHNO...
# 6048      Ad_lover_Dv  Aage baat karne ke liye kiripya iss link par c...
# 6049      irealistech  YOUTUBER @irealistech(link below)😊 also on ins...
# 6050  NaveenK83101785  M@n Oñ m!$$!०n|\nTô LiV€ ThE BeSt, CoM€ To mY ...
#
#                           location  following  followers  totaltweets  \
# ...

# %%
sarcastic_df = sarcastic_df[['text','label']]

# %%
non_sarcastic_df = non_sarcastic_df[['text','label']]

# %%
non_sarcastic_df.value_counts()
# Out:
# text                                                                                                                                                                                                                                                                                                            label
# सुकून कमाना है अब ग़ालिब\nनाम ओर शोहरत से तो मोत मिल जाती है?\n#क़िताब_ऐ_जिंदगी \n#SuicideSquad \n#rip #susantsinghrajput #Sad #lifestyle https://t.co/YerOuIjRHh                                                                                                                                               0        236
# यह सोचकर #दुखी न हों कि,\n\n                 #लोग आपको नहीं #समझते.\n\nक्योंकि...\n\n               #कांटे से #वजन को...\n\n                                 #मापा जा सकता है, \n\n                 #गुणवत्ता को नहीं !!                                                                                        0        225
# ...

# %%
sarcastic_df.value_counts()
# Out:
# text                                                                                                                                                                                                                                                                                                                    label
# अगर आज नेहरू जी होते तो शी जिनपिंग की बीवी को एडविना की तरह पटाकर सिगरेट पिलाकर अपने वश में कर लेते, और तिब्बत ही नहीं सीधे शंघाई पर कब्जा कर लेते...! \n\nइश्क़ और जंग में सब जायज़ है (नेहरू की किताब द ठरकी नेहरू से ) \n\nजय कांग्रेस.. आक थू 💦💦\n\n#कटाक्ष                                                         1        2120
# हमारे गांव में एक मास्टर जी रहते थे, वो मोहल्ले के बच्चों को अपने स्कूल आने को कहते थे। जब मैं बड़ा हुआ तो पता चला- स्कूल मास्टर के बेटे का, बस उनके भतीजे की, कैंटीन उनके भांजे की और  पढ़ाने वाले भी सब उनके रिश्तेदार ही थे..! \n\nआज मास्टर जी में सरकार में मंत्री हैं.! \n\n#कटाक्ष                               1         820
# ...

# %%
sarcastic_df
# Out:
#                                                    text  label
# 0     हमारे गांव में एक मास्टर जी रहते थे, वो मोहल्ल...      1
# 1     हमारे गांव में एक मास्टर जी रहते थे, वो मोहल्ल...      1
# 2     हमारे गांव में एक मास्टर जी रहते थे, वो मोहल्ल...      1
# 3     हमारे गांव में एक मास्टर जी रहते थे, वो मोहल्ल...      1
# 4     हमारे गांव में एक मास्टर जी रहते थे, वो मोहल्ल...      1
# ...                                                 ...    ...
# 6046  Sone Ki Chain Important Nhi Hoti\nBalki\nChain...      1
# 6047  @IACAbhi @myvivek1989 kya baat kr rhe ho..\n\n...      1
# 6048  Corona se Bachne Ke Liye Ghar par rahe\n.\n.\n...      1
# 6049  Me : kisi ne bataya tum kitni khubsurat ho?\n\...      1
# 6050  @MadhuTi1994 @Dr_Uditraj ये बन्दर का डांस देखे...      1
#
# [6051 rows x 2 columns]

# %%
# Combine both DataFrames
combined_df = pd.concat([sarcastic_df, non_sarcastic_df], ignore_index=True)

combined_df = combined_df.drop_duplicates()

# Randomize the data
df = combined_df.sample(frac=1, random_state=42).reset_index(drop=True)

# Save to a new CSV file if needed


print("Combined and randomized data:")
print(df.head())
# Out:
# Combined and randomized data:
#                                                 text  label
# 0  https://t.co/QIQPI0vqD7 नेता प्रतिपक्ष गुलाबचं...      0
# 1  जिस पल में आपको  #खुशियाँ मिली हैं,\nसच पूछिए ...      0
# 2  जीवन की धरा में पग-डग दिशा प्रदान करने वाले मे...      0
# 3  ज़ब #परिस्थिति बदल जाए तो #रणनीति #बदलना ही एक...      0
# 4  Aisa Nahi Hai Ke Bulane Se Aa Gaya😔😖...!!!\n.\...      0

# %%
pip install pandas googletrans==4.0.0-rc1
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.1/55.1 kB 2.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.4/133.4 kB 7.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.6/42.6 kB 1.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 2.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.0/65.0 kB 3.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 30.6 MB/s eta 0:00:00:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.6/53.6 kB 2.1 MB/s eta 0:00:00
# ...
#   Created wheel for googletrans: filename=googletrans-4.0.0rc1-py3-none-any.whl size=17395 sha256=c700fb44cb7e44149d4ba43dce772f4cbae616b8275ae9e349adfe07cb1645c5
#   Stored in directory: /root/.cache/pip/wheels/c0/59/9f/7372f0cf70160fe61b528532e1a7c8498c4becd6bcffb022de
# Successfully built googletrans
# ...
#   Attempting uninstall: h11
#     Found existing installation: h11 0.14.0
# ...

# %%
import pandas as pd
from googletrans import Translator

# Initialize the translator
translator = Translator()


# Function to translate text
def translate_text(text):
    try:
        translation = translator.translate(text, src='auto', dest='en')
        return translation.text
    except Exception as e:
        return text

# Translate the "Text" column
df['preprocessed_text'] = df['text'].apply(translate_text)


# Save the modified DataFrame back to a CSV file
df.to_csv('translated_english.csv', index=False)

# %%
processed_df['label'].value_counts()
# Out:
# label
# 0    869
# 1     90
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
print("Dataset Info:")
print(processed_df.info())
# Out:
# Dataset Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 959 entries, 0 to 958
# Data columns (total 3 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   label              959 non-null    int64
#  1   preprocessed_text  959 non-null    object
#  2   Text_Length        959 non-null    int64
# dtypes: int64(2), object(1)
# memory usage: 22.6+ KB
# None

# %%
# Describe the dataset
print("\nDataset Description:")
print(processed_df.describe(include='all'))
# Out:
# Dataset Description:
#              label preprocessed_text  Text_Length
# count   959.000000               959   959.000000
# unique         NaN               924          NaN
# top            NaN              Yeah          NaN
# freq           NaN                11          NaN
# mean      0.093848               NaN    50.849844
# std       0.291769               NaN    50.991448
# min       0.000000               NaN     1.000000
# 25%       0.000000               NaN    20.500000
# 50%       0.000000               NaN    35.000000
# 75%       0.000000               NaN    64.000000
# max       1.000000               NaN   516.000000

# %%
# Checking for missing values
missing_values = processed_df.isnull().sum()
print("\nMissing Values:")
print(missing_values)
# Out:
# Missing Values:
# label                0
# preprocessed_text    0
# Text_Length          0
# dtype: int64

# %%
label_counts = processed_df['label'].value_counts()
print("\nLabel Counts:")
print(label_counts)
# Out:
# Label Counts:
# label
# 0    869
# 1     90
# Name: count, dtype: int64

# %%
sarcasm_data = processed_df
sarcasm_data['Text_Length'] = sarcasm_data['preprocessed_text'].apply(len)

# %%
plt.figure(figsize=(8, 6))
sns.countplot(x='label', data=sarcasm_data, palette='viridis')
plt.title('Distribution of Sarcastic and Non-Sarcastic Labels')
plt.xlabel('Label')
plt.ylabel('Count')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.histplot(data=sarcasm_data, x='Text_Length', hue='label', kde=True, palette='viridis', bins=30)
plt.title('Distribution of Text Lengths by Label')
plt.xlabel('Text Length')
plt.ylabel('Frequency')
plt.show()
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# ...

# %%
import pandas as pd
import numpy as np 
from sklearn.model_selection import train_test_split

# %%
train, remaining = train_test_split(processed_df, test_size=0.2, random_state=42)

# Split the remaining 20% equally into dev (10%) and test (10%)
dev, test = train_test_split(remaining, test_size=0.5, random_state=42)

# Save the splits into separate CSV files
train_path = '/kaggle/working/hindi_train.csv'
dev_path = '/kaggle/working/hindi_dev.csv'
test_path = '/kaggle/working/hindi_test.csv'

train.to_csv(train_path, index=False)
dev.to_csv(dev_path, index=False)
test.to_csv(test_path, index=False)

print(f"Training set saved to {train_path}")
print(f"Development set saved to {dev_path}")
print(f"Test set saved to {test_path}")
# Out:
# Training set saved to /kaggle/working/hindi_train.csv
# Development set saved to /kaggle/working/hindi_dev.csv
# Test set saved to /kaggle/working/hindi_test.csv
